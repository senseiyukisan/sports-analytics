# %%
import pandas as pd

# %%
import gmaps
import gmaps.datasets

# %%
GMAPS_API_KEY = 'AIzaSyDlDwVSIW4OCOsBvPZztRU3imD49XjRjD4'

# %%
gmaps.configure(api_key=GMAPS_API_KEY)

# %%
clubs = pd.read_csv("data/clubs_updated.csv")

# %%
clubs.head(20)
# Out:
#     club_id                      name               pretty_name  \
# 0        27         fc-bayern-munchen         Fc Bayern Munchen
# 1        16         borussia-dortmund         Borussia Dortmund
# 2     23826    rasenballsport-leipzig    Rasenballsport Leipzig
# 3        15       bayer-04-leverkusen       Bayer 04 Leverkusen
# 4        18  borussia-monchengladbach  Borussia Monchengladbach
# 5        82             vfl-wolfsburg             Vfl Wolfsburg
# 6        24       eintracht-frankfurt       Eintracht Frankfurt
# 7       533       tsg-1899-hoffenheim       Tsg 1899 Hoffenheim
# 8        44                hertha-bsc                Hertha Bsc
# 9        79             vfb-stuttgart             Vfb Stuttgart
# 10       60               sc-freiburg               Sc Freiburg
# 11        3                 1-fc-koln                 1 Fc Koln
# 12       33             fc-schalke-04             Fc Schalke 04
# 13       86          sv-werder-bremen          Sv Werder Bremen
# ...

# %%
clubs['league_id'].unique()
# Out:
# array(['L1', 'ES1', 'GB1', 'FR1', 'IT1'], dtype=object)

# %%
import requests

# %%
def get_country(league_id):
    league_country_dict = {'L1': 'de', 'ES1': 'es', 'GB1': 'gb', 'FR1': 'fr', 'IT1': 'it'}
    return (league_country_dict[league_id])

def get_geocoords(club, country):
    GOOGLE_MAPS_API_URL = 'https://maps.googleapis.com/maps/api/geocode/json'
    
    params = {
        'address': club,
        'region': country,
        'key': GMAPS_API_KEY
    }
    
    response = requests.get(GOOGLE_MAPS_API_URL, params=params).json()
    print(response)
    result = response['results'][0]

    latitude = result['geometry']['location']['lat']
    longitude = result['geometry']['location']['lng']
    address = result['formatted_address']
    print(f'{club}:\naddress: {address}\nlatitude: {latitude} | longitude: {longitude}')
    return latitude, longitude
    

clubs['latitude'] = None
clubs['longitude'] = None

for ind, row in clubs.iterrows():
    league_id = row['league_id']
    country = get_country(league_id)
    
    club = row['name']
    lat, lon = get_geocoords(club, country)
    clubs.at[ind, 'latitude'] = lat
    clubs.at[ind, 'longitude'] = lon
# Out:
# {'results': [{'address_components': [{'long_name': 'Germany', 'short_name': 'DE', 'types': ['country', 'political']}, {'long_name': 'Guxhagen', 'short_name': 'Guxhagen', 'types': ['locality', 'political']}, {'long_name': 'Schwalm-Eder-Kreis', 'short_name': 'Schwalm-Eder-Kreis', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Kassel', 'short_name': 'KS', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Hessen', 'short_name': 'HE', 'types': ['administrative_area_level_1', 'political']}, {'long_name': '34302', 'short_name': '34302', 'types': ['postal_code']}], 'formatted_address': '34302 Guxhagen, Germany', 'geometry': {'location': {'lat': 51.207997, 'lng': 9.4828462}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 51.2093459802915, 'lng': 9.484195180291502}, 'southwest': {'lat': 51.2066480197085, 'lng': 9.481497219708498}}}, 'partial_match': True, 'place_id': 'ChIJP1pGHhlEu0cR1FUJpYpfLak', 'types': ['establishment', '
# ...

# %%
clubs.loc[54, 'longitude'] = -0.085556

# %%
clubs.head(60)
# Out:
#     club_id                         name                  pretty_name  \
# 0        27            fc-bayern-munchen            Fc Bayern Munchen
# 1        16            borussia-dortmund            Borussia Dortmund
# 2     23826       rasenballsport-leipzig       Rasenballsport Leipzig
# 3        15          bayer-04-leverkusen          Bayer 04 Leverkusen
# 4        18     borussia-monchengladbach     Borussia Monchengladbach
# 5        82                vfl-wolfsburg                Vfl Wolfsburg
# 6        24          eintracht-frankfurt          Eintracht Frankfurt
# 7       533          tsg-1899-hoffenheim          Tsg 1899 Hoffenheim
# 8        44                   hertha-bsc                   Hertha Bsc
# 9        79                vfb-stuttgart                Vfb Stuttgart
# 10       60                  sc-freiburg                  Sc Freiburg
# 11        3                    1-fc-koln                    1 Fc Koln
# ...

# %%
locations = clubs[['latitude', 'longitude']]
weights = clubs['market_value']

# %%
figure_layout = {'width': '500px', 'margin': '0 auto 0 auto'}
center = (47.6667, 3.6667)
fig = gmaps.figure(map_type='HYBRID', layout=figure_layout, center=center, zoom_level=4)
heatmap_layer = gmaps.heatmap_layer(locations, weights=weights)
heatmap_layer.max_intensity = 925020000
heatmap_layer.point_radius = 15
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px', margin='0 auto 0 auto', width='500px'))

# %%
clubs.to_csv("data/clubs_updated_latlon.csv", index=False)
